# %%
pip install chromadb
# Out:
# Collecting chromadb
#   Downloading chromadb-0.6.3-py3-none-any.whl (611 kB)
#      ------------------------------------ 611.1/611.1 kB 754.9 kB/s eta 0:00:00
# Collecting posthog>=2.4.0
#   Downloading posthog-3.8.3-py2.py3-none-any.whl (64 kB)
#      ---------------------------------------- 64.7/64.7 kB 3.4 MB/s eta 0:00:00
# Collecting grpcio>=1.58.0
#   Downloading grpcio-1.69.0-cp39-cp39-win_amd64.whl (4.4 MB)
#      ---------------------------------------- 4.4/4.4 MB 2.2 MB/s eta 0:00:00
# Collecting opentelemetry-api>=1.2.0
#   Downloading opentelemetry_api-1.29.0-py3-none-any.whl (64 kB)
#      ---------------------------------------- 64.3/64.3 kB 1.7 MB/s eta 0:00:00
# Collecting fastapi>=0.95.2
#   Downloading fastapi-0.115.6-py3-none-any.whl (94 kB)
#      ---------------------------------------- 94.8/94.8 kB 1.3 MB/s eta 0:00:00
# Collecting build>=1.0.3
#   Downloading build-1.2.2.post1-py3-none-any.whl (22 kB)
# Collecting mmh3>=4.0.1
#   Downloading mmh3-5.0.1-cp39-cp39-win_amd64.whl (39 kB)
# Requirement already satisfied: httpx>=0.27.0 in d:\softwares\anaconda\lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: numpy>=1.22.5 in d:\softwares\anaconda\lib\site-packages (from chromadb) (1.26.4)
# Collecting overrides>=7.3.1
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Collecting onnxruntime>=1.14.1
#   Downloading onnxruntime-1.19.2-cp39-cp39-win_amd64.whl (11.1 MB)
#      ---------------------------------------- 11.1/11.1 MB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers>=0.13.2 in d:\softwares\anaconda\lib\site-packages (from chromadb) (0.21.0)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.29.0-py3-none-any.whl (18 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0
#   Downloading opentelemetry_instrumentation_fastapi-0.50b0-py3-none-any.whl (12 kB)
# Requirement already satisfied: PyYAML>=6.0.0 in d:\softwares\anaconda\lib\site-packages (from chromadb) (6.0)
# Collecting typer>=0.9.0
#   Downloading typer-0.15.1-py3-none-any.whl (44 kB)
#      ---------------------------------------- 44.9/44.9 kB 2.2 MB/s eta 0:00:00
# Collecting kubernetes>=28.1.0
#   Downloading kubernetes-31.0.0-py2.py3-none-any.whl (1.9 MB)
#      ---------------------------------------- 1.9/1.9 MB 3.0 MB/s eta 0:00:00
# Collecting chroma-hnswlib==0.7.6
#   Downloading chroma_hnswlib-0.7.6-cp39-cp39-win_amd64.whl (151 kB)
#      -------------------------------------- 151.1/151.1 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: pydantic>=1.9 in d:\softwares\anaconda\lib\site-packages (from chromadb) (2.9.2)
# Requirement already satisfied: rich>=10.11.0 in d:\softwares\anaconda\lib\site-packages (from chromadb) (13.7.1)
# Collecting opentelemetry-sdk>=1.2.0
#   Downloading opentelemetry_sdk-1.29.0-py3-none-any.whl (118 kB)
#      -------------------------------------- 118.1/118.1 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: orjson>=3.9.12 in d:\softwares\anaconda\lib\site-packages (from chromadb) (3.10.14)
# Requirement already satisfied: tenacity>=8.2.3 in d:\softwares\anaconda\lib\site-packages (from chromadb) (8.2.3)
# Requirement already satisfied: typing_extensions>=4.5.0 in d:\softwares\anaconda\lib\site-packages (from chromadb) (4.12.2)
# Collecting pypika>=0.48.9
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ---------------------------------------- 67.3/67.3 kB 3.6 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: importlib-resources in d:\softwares\anaconda\lib\site-packages (from chromadb) (6.4.0)
# Collecting uvicorn[standard]>=0.18.3
#   Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
#      ---------------------------------------- 62.3/62.3 kB 3.5 MB/s eta 0:00:00
# Collecting tqdm>=4.65.0
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.5/78.5 kB 2.2 MB/s eta 0:00:00
# Collecting bcrypt>=4.0.1
#   Downloading bcrypt-4.2.1-cp39-abi3-win_amd64.whl (153 kB)
#      -------------------------------------- 153.1/153.1 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=19.1 in d:\softwares\anaconda\lib\site-packages (from build>=1.0.3->chromadb) (24.2)
# Requirement already satisfied: tomli>=1.1.0 in d:\softwares\anaconda\lib\site-packages (from build>=1.0.3->chromadb) (2.0.1)
# Requirement already satisfied: importlib-metadata>=4.6 in d:\softwares\anaconda\lib\site-packages (from build>=1.0.3->chromadb) (7.1.0)
# Collecting pyproject_hooks
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: colorama in d:\softwares\anaconda\lib\site-packages (from build>=1.0.3->chromadb) (0.4.5)
# Collecting starlette<0.42.0,>=0.40.0
#   Downloading starlette-0.41.3-py3-none-any.whl (73 kB)
#      ---------------------------------------- 73.2/73.2 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: anyio in d:\softwares\anaconda\lib\site-packages (from httpx>=0.27.0->chromadb) (3.5.0)
# Requirement already satisfied: httpcore==1.* in d:\softwares\anaconda\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.7)
# Requirement already satisfied: idna in d:\softwares\anaconda\lib\site-packages (from httpx>=0.27.0->chromadb) (3.3)
# Requirement already satisfied: certifi in d:\softwares\anaconda\lib\site-packages (from httpx>=0.27.0->chromadb) (2022.9.14)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\softwares\anaconda\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: google-auth>=1.0.1 in d:\softwares\anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.22.0)
# Collecting durationpy>=0.7
#   Downloading durationpy-0.9-py3-none-any.whl (3.5 kB)
# Requirement already satisfied: requests-oauthlib in d:\softwares\anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in d:\softwares\anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in d:\softwares\anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.58.0)
# Requirement already satisfied: six>=1.9.0 in d:\softwares\anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in d:\softwares\anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: urllib3>=1.24.2 in d:\softwares\anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.26.11)
# Requirement already satisfied: requests in d:\softwares\anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.28.1)
# Requirement already satisfied: sympy in d:\softwares\anaconda\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.1)
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ---------------------------------------- 46.0/46.0 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: protobuf in d:\softwares\anaconda\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (3.20.3)
# Requirement already satisfied: flatbuffers in d:\softwares\anaconda\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (23.5.26)
# Collecting deprecated>=1.2.6
#   Downloading Deprecated-1.2.15-py2.py3-none-any.whl (9.9 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.29.0
#   Downloading opentelemetry_exporter_otlp_proto_common-1.29.0-py3-none-any.whl (18 kB)
# Collecting googleapis-common-protos~=1.52
#   Downloading googleapis_common_protos-1.66.0-py2.py3-none-any.whl (221 kB)
#      -------------------------------------- 221.7/221.7 kB 2.7 MB/s eta 0:00:00
# Collecting opentelemetry-proto==1.29.0
#   Downloading opentelemetry_proto-1.29.0-py3-none-any.whl (55 kB)
#      ---------------------------------------- 55.8/55.8 kB 3.0 MB/s eta 0:00:00
# Collecting protobuf
#   Downloading protobuf-5.29.3-cp39-cp39-win_amd64.whl (434 kB)
#      -------------------------------------- 434.6/434.6 kB 3.4 MB/s eta 0:00:00
# Collecting opentelemetry-instrumentation-asgi==0.50b0
#   Downloading opentelemetry_instrumentation_asgi-0.50b0-py3-none-any.whl (16 kB)
# Collecting opentelemetry-semantic-conventions==0.50b0
#   Downloading opentelemetry_semantic_conventions-0.50b0-py3-none-any.whl (166 kB)
#      -------------------------------------- 166.6/166.6 kB 2.0 MB/s eta 0:00:00
# Collecting opentelemetry-util-http==0.50b0
#   Downloading opentelemetry_util_http-0.50b0-py3-none-any.whl (6.9 kB)
# Collecting opentelemetry-instrumentation==0.50b0
#   Downloading opentelemetry_instrumentation-0.50b0-py3-none-any.whl (30 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in d:\softwares\anaconda\lib\site-packages (from opentelemetry-instrumentation==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Collecting asgiref~=3.0
#   Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Collecting monotonic>=1.5
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Requirement already satisfied: backoff>=1.10.0 in d:\softwares\anaconda\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\softwares\anaconda\lib\site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in d:\softwares\anaconda\lib\site-packages (from pydantic>=1.9->chromadb) (2.23.4)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\softwares\anaconda\lib\site-packages (from rich>=10.11.0->chromadb) (2.17.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\softwares\anaconda\lib\site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in d:\softwares\anaconda\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.27.1)
# Requirement already satisfied: click>=8.0.0 in d:\softwares\anaconda\lib\site-packages (from typer>=0.9.0->chromadb) (8.0.4)
# Collecting shellingham>=1.3.0
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Requirement already satisfied: python-dotenv>=0.13 in d:\softwares\anaconda\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Collecting websockets>=10.4
#   Downloading websockets-14.1-cp39-cp39-win_amd64.whl (163 kB)
#      -------------------------------------- 163.3/163.3 kB 2.5 MB/s eta 0:00:00
# Collecting watchfiles>=0.13
#   Downloading watchfiles-1.0.4-cp39-cp39-win_amd64.whl (284 kB)
#      -------------------------------------- 284.9/284.9 kB 2.2 MB/s eta 0:00:00
# Collecting httptools>=0.6.3
#   Downloading httptools-0.6.4-cp39-cp39-win_amd64.whl (89 kB)
#      ---------------------------------------- 89.6/89.6 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=3.1.0 in d:\softwares\anaconda\lib\site-packages (from importlib-resources->chromadb) (3.8.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\softwares\anaconda\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\softwares\anaconda\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\softwares\anaconda\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in d:\softwares\anaconda\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.6.0)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\softwares\anaconda\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.12.0)
# Requirement already satisfied: mdurl~=0.1 in d:\softwares\anaconda\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\softwares\anaconda\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (2.0.4)
# Requirement already satisfied: sniffio>=1.1 in d:\softwares\anaconda\lib\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.2.0)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ---------------------------------------- 86.8/86.8 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\softwares\anaconda\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.2.1)
# Collecting pyreadline3
#   Downloading pyreadline3-3.5.4-py3-none-any.whl (83 kB)
#      ---------------------------------------- 83.2/83.2 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\softwares\anaconda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml): started
#   Building wheel for pypika (pyproject.toml): finished with status 'done'
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53885 sha256=165391b20c21bf20945a9480d8561f9658dfd0511e2f4e9199dd846969480a5b
#   Stored in directory: c:\users\dulara\appdata\local\pip\cache\wheels\f7\02\64\d541eac67ec459309d1fb19e727f58ecf7ffb4a8bf42d4cfe5
# Successfully built pypika
# Installing collected packages: pypika, monotonic, durationpy, websockets, tqdm, shellingham, pyreadline3, pyproject_hooks, protobuf, overrides, opentelemetry-util-http, mmh3, httptools, grpcio, deprecated, chroma-hnswlib, bcrypt, asgiref, watchfiles, uvicorn, starlette, posthog, opentelemetry-proto, opentelemetry-api, humanfriendly, googleapis-common-protos, build, typer, opentelemetry-semantic-conventions, opentelemetry-exporter-otlp-proto-common, kubernetes, fastapi, coloredlogs, opentelemetry-sdk, opentelemetry-instrumentation, onnxruntime, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-instrumentation-fastapi, chromadb
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.1
#     Uninstalling tqdm-4.64.1:
#       Successfully uninstalled tqdm-4.64.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.57.0
#     Uninstalling grpcio-1.57.0:
#       Successfully uninstalled grpcio-1.57.0
#   Attempting uninstall: bcrypt
#     Found existing installation: bcrypt 3.2.0
#     Uninstalling bcrypt-3.2.0:
#       Successfully uninstalled bcrypt-3.2.0
# Successfully installed asgiref-3.8.1 bcrypt-4.2.1 build-1.2.2.post1 chroma-hnswlib-0.7.6 chromadb-0.6.3 coloredlogs-15.0.1 deprecated-1.2.15 durationpy-0.9 fastapi-0.115.6 googleapis-common-protos-1.66.0 grpcio-1.69.0 httptools-0.6.4 humanfriendly-10.0 kubernetes-31.0.0 mmh3-5.0.1 monotonic-1.6 onnxruntime-1.19.2 opentelemetry-api-1.29.0 opentelemetry-exporter-otlp-proto-common-1.29.0 opentelemetry-exporter-otlp-proto-grpc-1.29.0 opentelemetry-instrumentation-0.50b0 opentelemetry-instrumentation-asgi-0.50b0 opentelemetry-instrumentation-fastapi-0.50b0 opentelemetry-proto-1.29.0 opentelemetry-sdk-1.29.0 opentelemetry-semantic-conventions-0.50b0 opentelemetry-util-http-0.50b0 overrides-7.7.0 posthog-3.8.3 protobuf-5.29.3 pypika-0.48.9 pyproject_hooks-1.2.0 pyreadline3-3.5.4 shellingham-1.5.4 starlette-0.41.3 tqdm-4.67.1 typer-0.15.1 uvicorn-0.34.0 watchfiles-1.0.4 websockets-14.1
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# anaconda-project 0.11.1 requires ruamel-yaml, which is not installed.
# tensorflow-intel 2.13.0 requires numpy<=1.24.3,>=1.22, but you have numpy 1.26.4 which is incompatible.
# tensorflow-intel 2.13.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.29.3 which is incompatible.
# tensorflow-intel 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.12.2 which is incompatible.
# streamlit 1.32.1 requires packaging<24,>=16.8, but you have packaging 24.2 which is incompatible.
# streamlit 1.32.1 requires protobuf<5,>=3.20, but you have protobuf 5.29.3 which is incompatible.
# mediapipe 0.10.9 requires protobuf<4,>=3.11, but you have protobuf 5.29.3 which is incompatible.

# %%
import chromadb

client = chromadb.Client()
collection = client.create_collection(name="my_collection")

# %%
collection.add(
    documents=[
        "This document is about New York",
        "This document about Delhi"
    ],
    ids = ['id1','id2']
)
# Out:
# C:\Users\dulara\.cache\chroma\onnx_models\all-MiniLM-L6-v2\onnx.tar.gz: 100%|████| 79.3M/79.3M [00:28<00:00, 2.89MiB/s]

# %%
all_docs = collection.get()
all_docs
# Out:
# {'ids': ['id1', 'id2'],
#  'embeddings': None,
#  'documents': ['This document is about New York', 'This document about Delhi'],
#  'uris': None,
#  'data': None,
#  'metadatas': [None, None],
#  'included': [<IncludeEnum.documents: 'documents'>,
#   <IncludeEnum.metadatas: 'metadatas'>]}

# %%
results = collection.query(
    query_texts = ['Query is about Pizza'],
    n_results=2
)
results
# Out:
# {'ids': [['id1', 'id2']],
#  'embeddings': None,
#  'documents': [['This document is about New York',
#    'This document about Delhi']],
#  'uris': None,
#  'data': None,
#  'metadatas': [[None, None]],
#  'distances': [[1.6637976169586182, 1.7169506549835205]],
#  'included': [<IncludeEnum.distances: 'distances'>,
#   <IncludeEnum.documents: 'documents'>,
#   <IncludeEnum.metadatas: 'metadatas'>]}
